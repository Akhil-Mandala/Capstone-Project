# %% [markdown]
# # CAPSTONE PROJECT

# %% [markdown]
# ## Problem Statement
#  Solving this problem will help you to gain a basic understanding of the HR industry and also how analytics and data science are applied in practice in this domain.

# %% [markdown]
# ## Understanding the Problem Statement
# In this project, you will have to put yourself in the shoes of an HR analytics expert and by leveraging the data provided, you are supposed to identify how salary is varying with respect to other considerable factors.

# %% [markdown]
# ## Dependent Variable
# how salary is varying with respect to other considerable factors.

# %% [markdown]
# ### In the capstone project as the first step is to understand the data set.so, i have imported the required libraries and then imported the data set.

# %%
#importing the required libraries numpy as np, pandas as pd ,matplotlib.pyplot as plt and seaborn as sns.
import numpy as np
import pandas as pd
# Libraries for data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings#allows you to handle all warnings
warnings.filterwarnings('ignore')#"ignore"never print matching warnings

# %%
#In this we are reading the data using pandas as pd and read_csv as the type of the data set given.
df = pd.read_csv("New_data_Set.csv")
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %% [raw]
# The data set is about the details of the employee's of a compony under the sales department.Every column in the data goes with
# Gender - talks of the gender - Male or female
# -Business - if the person has a business or no
# -Age - age of the person
# -Salary - CTC of the employee
# -Dependants - number of people dependant on the person
# -Months - duration of the person employed with the company
# -Calls - if the person has authority to make calls or not
# -Type - salary settlement type
# -Billing - Subscribed to billing plans or no
# -Unit sales - unit sale made by the person
# -Total sales - total sales made by the person
# -Rating - If he has been given a rating by a superior or no
# -Bonus - amount received by a person as bonus for sales
# -Base pay - Base pay of the employee
# -Unit price - The Unit price of a sale
# -Volume - volume allotted to a person
# -Opening balance - The opening balance of an employee
# -Low - lowest balance allotted to a person.
# -Closing Balance- The closing balance of an employee
# -Education- Educational background of an employee
# this columns explain the type of data that is been given of the 5000 employee's.

# %% [markdown]
# ### 1.Understanding the data set

# %%
#Looking the head of the data set which is top 5 columns of the data.
df.head()
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
#
#     Salary  Base_pay     Bonus  Unit_Price    Volume  openingbalance  \
# 0  5089.00  2035.600  254.4500        3.77  21226600            3.75
# 1  5698.12  2279.248  284.9060        3.74  10462800            3.85
# 2  5896.65  2358.660  294.8325        3.89  18761000            4.23
# 3  6125.12  2450.048  306.2560        4.35  66130600            4.26
# 4  6245.00  2498.000  312.2500        4.34  26868200            4.79
#
#    closingbalance   low  Unit_Sales Total_Sales  Months            Education
# ...

# %%
#Looking the tail of the data set which is bottom 5 columns of the data.
df.tail()
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#          Salary   Base_pay     Bonus  Unit_Price   Volume  openingbalance  \
# 4995  180696.80  72278.720  9034.840  629.511067  3927000             NaN
# 4996  185685.90  74274.360  9284.295  627.841071  6031900             NaN
# 4997  192636.80  77054.720  9631.840  625.860033  7949400             NaN
# 4998  195970.70  78388.280  9798.535  629.510005  3908400             NaN
# 4999  199970.74  79988.296  9998.537  627.839984  6003300             NaN
#
# ...

# %%
#Looking at the shape of the dataset.We have 5000 rows and 20 columns
df.shape
# Out:
# (5000, 20)

# %%
#df.size representing the number of elements in this object.
df.size
# Out:
# 100000

# %%
#This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
#df.describe() Generates descriptive statistics.
#Descriptive statistics include those that summarize the centraltendency,
# dispersion and shape of dataset's distribution, excluding ``NaN`` values.
df.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   4977.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10135.686075  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33720.552420  4194.516950
# 50%       0.000000    52.000000  100579.378500  40282.016040  5028.968925
# 75%       0.000000    57.000000  116912.092475  46792.232410  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     3524.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %%
df.Business = df.Business.astype('object')# #Bussiness is a categorical data but python is reading it as integer

# %%
df.describe( include= ['object'])#description of catogorical features
# Out:
#        Gender  Business Dependancies Calls            Type Billing Rating  \
# count    5000      5000         5000  5000            5000    5000   5000
# unique      2         2            2     2               3       2      2
# top      Male         0           No   Yes  Month-to-month     Yes     No
# freq     2528      4200         3524  4539            2777    2956   3682
#
#        Total_Sales Education
# count         4992      5000
# unique        4706         4
# top                       PG
# freq             8      2979

# %%
#Looking at the sum of null values in each column.Base_pay colums has 23 NaN values,
# Openingbalance has 1476 NaN values & Total_sales has 8 NaN values.
df.isnull().sum()
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales          8
# Months               0
# Education            0
# dtype: int64

# %%
#df.isnull().sum()/len(df)*100 generates null percentage of each column in which we found 0.46% in Base_pay,
# 29.52 in openbalancing & 0.16 of null values in Total_sales.
df.isnull().sum()/len(df)*100
# Out:
# Gender             0.00
# Business           0.00
# Dependancies       0.00
# Calls              0.00
# Type               0.00
# Billing            0.00
# Rating             0.00
# Age                0.00
# Salary             0.00
# Base_pay           0.46
# Bonus              0.00
# Unit_Price         0.00
# Volume             0.00
# openingbalance    29.52
# closingbalance     0.00
# low                0.00
# Unit_Sales         0.00
# Total_Sales        0.16
# Months             0.00
# Education          0.00
# dtype: float64

# %%
mv=df.isnull().sum().sum() #To know the total sum of the null values present in the data and giving it to the variable mv(missing values).
ds=df.size #Looking at the size of the data set and calling it to the variable ds(data size).
missing_values=(mv/ds)*100 #Calculating the percentage of the missing values in the data set.
missing_values #We have 1.5% of null values in the complete dataset.
# Out:
# 1.5070000000000001

# %%
df.duplicated().sum() #Checking if there are any duplicates in the date and we have found no duplictes.
# Out:
# 0

# %%
df['Gender'].value_counts() #To count the values of the Gender in which the data has 2528 male employee's and 2472 female employee's.
# Out:
# Male      2528
# Female    2472
# Name: Gender, dtype: int64

# %%
print(df['Business'].value_counts()) #To count the values of the Business in which the data has 4200 employee's with 0 business and 800 employee's with 1 business.
df['Business'].value_counts().plot(kind='bar') #Plotting the values of business column on bar plot.
# Out:
# 0    4200
# 1     800
# Name: Business, dtype: int64
# <AxesSubplot:>

# %%
print(df['Dependancies'].value_counts()) #To count the values of the Dependancies in which the data has 3524 employee's 
#with no dependancies and 1476 empolyee's with dependancies on them.
df['Dependancies'].value_counts().plot(kind='bar') #Plotting the values of Dependancies column on bar plot.
# Out:
# No     3524
# Yes    1476
# Name: Dependancies, dtype: int64
# <AxesSubplot:>

# %%
print(df['Calls'].value_counts()) #To count the values of the Calls in which the data has 4539 has authority to make calls 
#and 461 has no authority to make calls.
df['Calls'].value_counts().plot(kind='bar') #Plotting the values of Calls column on bar plot.
# Out:
# Yes    4539
# No      461
# Name: Calls, dtype: int64
# <AxesSubplot:>

# %%
print(df['Type'].value_counts()) #To count the values of the Type (salary settlement type) in which 2777 has Month-to-month settlement,
#1195 has Two year settlement and 1028 with One year settlement.
df['Type'].value_counts().plot(kind='bar') #Plotting the values of Type column on bar plot.
# Out:
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: Type, dtype: int64
# <AxesSubplot:>

# %%
print(df['Billing'].value_counts()) #To count the values of the Billing(Subscribed to billing plans or no)
#in which 2956 has Subscribed to billing plans and 2044 has not Subscribed to billing plans.
df['Billing'].value_counts().plot(kind='bar') #Plotting the values of Billing column on bar plot.
# Out:
# Yes    2956
# No     2044
# Name: Billing, dtype: int64
# <AxesSubplot:>

# %%
print(df['Rating'].value_counts())#To count the values of Rating(If he has been given a rating by a superior or no) in which 
#3682 employee's has no rating by a superior and 1318 has been given a rating by a superior.
df['Rating'].value_counts().plot(kind='bar') #Plotting the values of Rating column on bar plot.
# Out:
# No     3682
# Yes    1318
# Name: Rating, dtype: int64
# <AxesSubplot:>

# %%
print(df['Education'].value_counts())#To count the values of Education(Educational background of an employee) in which 2979 has PG background, 
#1980 has graduation background, 27 has intermediate backgroung and 14 has high school or less backgroung.
df['Education'].value_counts().plot(kind='bar') #Plotting the values of Education column on bar plot.
# Out:
# PG                     2979
# Graduation             1980
# Intermediate             27
# High School or less      14
# Name: Education, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ### 2.Check the number of variables that are normally distributed & explain

# %%
#We found ' '(space) is given as a value in Total_sales column by using index function.
df[df['Total_Sales']==' ']
# Out:
#       Gender Business Dependancies Calls            Type Billing Rating  Age  \
# 4992    Male        1           No   Yes        One year      No     No   71
# 4993    Male        0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male        0           No   Yes  Month-to-month     Yes     No   71
# 4995  Female        0           No   Yes  Month-to-month      No     No   72
# 4996    Male        0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male        0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male        1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male        0          Yes   Yes        Two year     Yes     No   88
#
#            Salary     Base_pay        Bonus  Unit_Price   Volume  \
# 4992  170372.5473  68149.01893  8518.627365  312.700012   295300
# 4993  170639.5565  68255.82259  8531.977825  314.000000   294600
# 4994  175689.3000  70275.72000  8784.465000  625.861078  7987100
# ...

# %%
#We found ' '(space) is given as a value in Total_sales column by using index function we found the rows containing space as
#value and replaceing then using replace function.
df['Total_Sales'].replace({' ' : 'NaN'}, inplace=True)
df['Total_Sales']=df['Total_Sales'].astype(float) #Converting the datatype of total_sales into float from object type.

# %%
#Categorizing the dataset into numarical & categorical
df_num = df.select_dtypes(include=[np.number]) #Categorizing the dataset numarical variables into df_num.
df_cat = df.select_dtypes(exclude=[np.number]) #categorizing the dataset categorical variables into df_cat.

# %%
#Looking the head of the data set which is top 5 columns of the data.
df_num.head()
# Out:
#    Age   Salary  Base_pay     Bonus  Unit_Price    Volume  openingbalance  \
# 0   18  5089.00  2035.600  254.4500        3.77  21226600            3.75
# 1   19  5698.12  2279.248  284.9060        3.74  10462800            3.85
# 2   22  5896.65  2358.660  294.8325        3.89  18761000            4.23
# 3   21  6125.12  2450.048  306.2560        4.35  66130600            4.26
# 4   23  6245.00  2498.000  312.2500        4.34  26868200            4.79
#
#    closingbalance   low  Unit_Sales  Total_Sales  Months
# 0            3.76  3.65       18.25        18.80       0
# 1            3.68  3.65       18.40        18.85       0
# 2            4.29  3.72       18.70        18.90       0
# 3            4.31  3.83       18.75        19.00       0
# 4            4.41  4.08       18.80        19.05       1

# %%
#Looking the head of the data set which is top 5 columns of the data.
df_cat
# Out:
#       Gender Business Dependancies Calls            Type Billing Rating  \
# 0     Female        0           No   Yes  Month-to-month      No    Yes
# 1     Female        0           No   Yes  Month-to-month      No    Yes
# 2       Male        0           No   Yes  Month-to-month     Yes     No
# 3     Female        1           No   Yes  Month-to-month     Yes    Yes
# 4       Male        0           No   Yes  Month-to-month     Yes    Yes
# ...      ...      ...          ...   ...             ...     ...    ...
# 4995  Female        0           No   Yes  Month-to-month      No     No
# 4996    Male        0           No   Yes  Month-to-month     Yes     No
# 4997    Male        0           No   Yes  Month-to-month     Yes     No
# 4998    Male        1           No   Yes  Month-to-month     Yes    Yes
# 4999    Male        0          Yes   Yes        Two year     Yes     No
#
#                 Education
# 0     High School or less
# 1     High School or less
# ...

# %%
# Check the relationship of all the numerical features with Salary using pairplot.
sns.set({'figure.figsize':(20,20)})
sns.pairplot(data=df, y_vars='Salary',hue='Gender', diag_kind=None)
plt.show() 
#1.Salary ,basepay and bonus are normally distributed
#2.No linear relationship is observed between independent varaiables and dependent variable(Salary).

# %%
from scipy.stats import skew #importing skew from scipy.statistics library
for col in df_num: #creating for loop within the columns in df_num
    print(f'Skewness:',skew(df_num[col])) #to print the skewness of df_num columns
    
    plt.figure()
    sns.distplot(df_num[col]) #plotting distribution plot in the df_num columns.
    plt.show()
# Out:
# Skewness: -0.25989346454123136
# Skewness: -0.3959227776154577
# Skewness: nan
# Skewness: -0.3959227777431069
# Skewness: 5.987865994265544
# Skewness: 8.707122057422051
# Skewness: nan
# Skewness: 3.2254000593916365
# Skewness: 3.2326965274396677
# Skewness: -0.22537960434031343
# Skewness: nan
# Skewness: 0.2571966118774309

# %% [markdown]
# we found out the distribution of all the numarical data types and we found there are normally distributed , moderate skewed & highly skewed
# As we know -0.5 to 0.5 range is normally distributed
#         -1 to 0.5 and 0.5 to 1 is moderate skewed
#          above -1 to above 1 is highly skewed
# we have Age, Salary, Bonus, Unit_Sales, Months are normally distributed

# %%
df_num['Base_pay'].skew() #cheking the skewness of Base_pay.
# Out:
# -0.36419479825248674

# %%
df_num['openingbalance'].skew() #cheking the skewness of openingbalance.
# Out:
# 3.3127435798934117

# %%
df_num['Total_Sales'].skew() #cheking the skewness of Total_Sales.
# Out:
# 0.9718782430989669

# %% [markdown]
# ## Age, Salary,Base_pay, Bonus, Unit_Sales, Months are normally distributed

# %% [markdown]
# ### 3.Find out the correlation between variables using spearman rank correlation & explain

# %%
df_num.corr(method='spearman')#Looking at the spearman rank correlation between the numerical variables.
# Out:
#                      Age    Salary  Base_pay     Bonus  Unit_Price    Volume  \
# Age             1.000000  0.202282  0.193690  0.202282    0.128266 -0.039345
# Salary          0.202282  1.000000  0.999976  1.000000    0.811713 -0.390488
# Base_pay        0.193690  0.999976  1.000000  0.999976    0.811679 -0.390787
# Bonus           0.202282  1.000000  0.999976  1.000000    0.811713 -0.390488
# Unit_Price      0.128266  0.811713  0.811679  0.811713    1.000000 -0.324230
# Volume         -0.039345 -0.390488 -0.390787 -0.390488   -0.324230  1.000000
# openingbalance  0.068410  0.297932  0.291481  0.297932    0.172338 -0.024988
# closingbalance  0.440989  0.346498  0.339959  0.346498    0.263699 -0.147108
# low             0.202040  0.999859  0.999832  0.999859    0.812412 -0.392209
# Unit_Sales      0.202268  0.999997  0.999973  0.999997    0.811735 -0.390505
# Total_Sales     0.196744  1.000000  0.999975  1.000000    0.810661 -0.391428
# ...

# %%
plt.figure(figsize=(20,10))#Plotting the spearman rank correlation on heat map.
sns.heatmap(df_num.corr(method='spearman'),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #
#  The Spearmen's rank correlation coefficient is the non-parametric statistical measure used to study the strength of association between two or more ranked variables and we found correlation between the variables 0.6 to 1 is measured as the high correlation

# %% [markdown]
# ### 4.Examine the relationship between categorical variables and the dependent variable

# %%
# To Examine the relationship between categorical variables and the dependent variable(Salary),
#Using boxplots for all categorical values with the help of subplots 
fig,((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8))=plt.subplots(4,2,figsize=(12,12))   # Plotting size of figure
fig.tight_layout()                      # Plotting layout of each subplot
sns.boxplot(x = 'Gender', y = 'Salary', data = df,ax=ax1)
sns.boxplot(x = 'Business', y = 'Salary', data = df,ax=ax2)
sns.boxplot(x = 'Dependancies', y = 'Salary', data = df,ax=ax3)
sns.boxplot(x = 'Calls', y = 'Salary', data = df,ax=ax4)
sns.boxplot(x = 'Type', y = 'Salary', data = df,ax=ax5,)
sns.boxplot(x = 'Billing', y = 'Salary', data = df,ax=ax6)
sns.boxplot(x = 'Rating', y = 'Salary', data = df,ax=ax7)
sns.boxplot(x = 'Education', y = 'Salary', data = df,ax=ax8)
plt.show()

# %% [markdown]
# Except the Education column we can not see any variabiity in the features and their variable like in Gender male and female are having same salary, if a person has a bussiness or not it doesnt affect his salary, if the person has no. of dependent people in their family or not the salary would be same, if a person can make a call or not the salary would remain same, type of settlement also doesnt get affected, subscribed to billing or not and if he has been rated or not all these would not affect the salary so we can remove them.
#
# In Education we can see people with higher education are paid more.

# %% [markdown]
# ### 5.Clean and pre-process the data with other operations required, like, missing values, handling outliers, etc. as and when necessary

# %% [markdown]
# #### i.Missing values operation

# %%
df_num.isnull().sum() #Looking at the sum of null values in each column.
# Out:
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales         16
# Months               0
# dtype: int64

# %%
#Checking the mean of the column base_pay as it is normally distributed and calling it to a variable and
#replacing the null values with mean using fillna() function.
mean_value=df_num['Base_pay'].mean()
df_num['Base_pay']=df_num['Base_pay'].fillna(mean_value)

# %%
#Checking the median of the column openingbalance as it is skewed and calling it to a variable and 
#replacing the null values with median using fillna() function.
median_value=df_num['openingbalance'].median()
df_num['openingbalance']=df_num['openingbalance'].fillna(median_value)

# %%
#Checking the median of the column Total_Sales as it is skewwd and calling it to a variable
#and replacing the null values with median using fillna() function.
median_value=df_num['Total_Sales'].median()
df_num['Total_Sales']=df_num['Total_Sales'].fillna(median_value)

# %%
df_num.isnull().sum() #Checking the null values of the columns and we found no nulls.
# Out:
# Age               0
# Salary            0
# Base_pay          0
# Bonus             0
# Unit_Price        0
# Volume            0
# openingbalance    0
# closingbalance    0
# low               0
# Unit_Sales        0
# Total_Sales       0
# Months            0
# dtype: int64

# %%
df_num.dtypes #Checking the datatypes of the columns.
# Out:
# Age                 int64
# Salary            float64
# Base_pay          float64
# Bonus             float64
# Unit_Price        float64
# Volume              int64
# openingbalance    float64
# closingbalance    float64
# low               float64
# Unit_Sales        float64
# Total_Sales       float64
# Months              int64
# dtype: object

# %% [markdown]
# #### ii.Handling outliers

# %%
for col in df_num: #creating for loop within the columns in df_num
    sns.boxplot(df_num[col]) #plotting boxplot on df_num columns to check outlies.
    plt.show()

# %% [markdown]
#  When we look at the boxplot of ever column, we see outliers over upper&lower whisker in Age, salary, Base_pay & Bonus columns.
# we see outliers over upper whisker in Unit_Price, Volume, openingbalance, closingbalance & low columns.
# And we see no outliers in Unit_Sales, Total_Sales, Months.

# %%
df_num['Age'].describe() #To check all the statistical values of Age column.
# Out:
# count    5000.000000
# mean       51.865000
# std         8.560691
# min        18.000000
# 25%        47.000000
# 50%        52.000000
# 75%        57.000000
# max        88.000000
# Name: Age, dtype: float64

# %%
#Calculating the quantiles of Age.
q1 = np.quantile(df_num['Age'],0.25)
q2 = np.quantile(df_num['Age'],0.50)
q3 = np.quantile(df_num['Age'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 47.0 |q2 = 52.0|q3 = 57.0

# %%
IQR = q3-q1 #Calculating IQR(linear quadratic regulator).
IQR
# Out:
# 10.0

# %%
#Calculating the Upperwhisker and lowerwhisker.
Upperwhisker = q3+(1.5*IQR)
Lowerwhisker = q1-(1.5*IQR)

# %%
#Replaying outliers into upperwhisker and lowerwhisker.
df_num['Age'] = df_num['Age'][(df_num['Age'] >= Lowerwhisker) & (df_num['Age'] <= Upperwhisker)]

# %%
#Checking the outliers in column Age using boxplot after handling outliers.
sns.boxplot(df_num['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df_num['Salary'].describe()#To check all the statistical values of Salary column.
# Out:
# count      5000.000000
# mean      99821.928553
# std       25376.961744
# min        5089.000000
# 25%       83890.338980
# 50%      100579.378500
# 75%      116912.092475
# max      199970.740000
# Name: Salary, dtype: float64

# %%
#Calculating the quantiles of Salary.
q1 = np.quantile(df_num['Salary'],0.25)
q2 = np.quantile(df_num['Salary'],0.50)
q3 = np.quantile(df_num['Salary'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 83890.33898 |q2 = 100579.3785|q3 = 116912.092475

# %%
IQR = q3-q1 #Calculating IQR(linear quadratic regulator).
IQR
# Out:
# 33021.753495

# %%
#Calculating the Upperwhisker and lowerwhisker.
Upperwhisker = q3+(1.5*IQR)
Lowerwhisker = q1-(1.5*IQR)

# %%
#Replaying outliers into upperwhisker and lowerwhisker.
df_num['Salary'] = df_num['Salary'][(df_num['Salary'] >= Lowerwhisker) & (df_num['Salary'] <= Upperwhisker)]

# %%
#Checking the outliers in column Salary using boxplot after handling outliers.
sns.boxplot(df_num['Salary'])
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
df_num['Base_pay'].describe() #To check all the statistical values of Base_pay column.
# Out:
# count     5000.000000
# mean     40046.187707
# std      10112.342452
# min       2035.600000
# 25%      33744.021630
# 50%      40231.751415
# 75%      46764.836975
# max      79988.296000
# Name: Base_pay, dtype: float64

# %%
#Calculating the quantiles of Base_pay.
q1 = np.quantile(df_num['Base_pay'],0.25)
q2 = np.quantile(df_num['Base_pay'],0.50)
q3 = np.quantile(df_num['Base_pay'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 33744.02163 |q2 = 40231.751415000006|q3 = 46764.836975

# %%
IQR = q3-q1 #Calculating IQR(linear quadratic regulator).
IQR
# Out:
# 13020.815344999995

# %%
Upperwhisker = q3+(1.5*IQR) #Calculating the Upperwhisker and lowerwhisker.
Lowerwhisker = q1-(1.5*IQR)

# %%
#Replaying outliers into upperwhisker and lowerwhisker.
df_num['Base_pay'] = df_num['Base_pay'][(df_num['Base_pay'] >= Lowerwhisker) & (df_num['Base_pay'] <= Upperwhisker)]

# %%
#Checking the outliers in column Base_pay using boxplot after handling outliers.
sns.boxplot(df_num['Base_pay'])
# Out:
# <AxesSubplot:xlabel='Base_pay'>

# %%
df_num['Bonus'].describe() #To check all the statistical values of Bonus column.
# Out:
# count    5000.000000
# mean     4991.096428
# std      1268.848087
# min       254.450000
# 25%      4194.516950
# 50%      5028.968925
# 75%      5845.604624
# max      9998.537000
# Name: Bonus, dtype: float64

# %%
#Calculating the quantiles of Bonus.
q1 = np.quantile(df_num['Bonus'],0.25)
q2 = np.quantile(df_num['Bonus'],0.50)
q3 = np.quantile(df_num['Bonus'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 4194.5169495 |q2 = 5028.968925|q3 = 5845.60462375

# %%
IQR = q3-q1#Calculating IQR(linear quadratic regulator)
IQR
# Out:
# 1651.0876742500004

# %%
Upperwhisker = q3+(1.5*IQR) #Calculating the Upperwhisker and lowerwhisker.
Lowerwhisker = q1-(1.5*IQR)

# %%
#Replaying outliers into upperwhisker and lowerwhisker.
df_num['Bonus'] = df_num['Bonus'][(df_num['Bonus'] >= Lowerwhisker) & (df_num['Bonus'] <= Upperwhisker)]

# %%
#Checking the outliers in column Bonus using boxplot after handling outliers.
sns.boxplot(df_num['Bonus'])
# Out:
# <AxesSubplot:xlabel='Bonus'>

# %%
#Calculating the quantiles of Unit_Price.
q1 = np.quantile(df_num['Unit_Price'],0.25)
q2 = np.quantile(df_num['Unit_Price'],0.50)
q3 = np.quantile(df_num['Unit_Price'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 25.72749975 |q2 = 39.205|q3 = 58.71500025

# %%
IQR = q3-q1 #Calculating IQR(linear quadratic regulator)
IQR
# Out:
# 32.9875005

# %%
Upperwhisker = q3+(1.5*IQR) #Calculating the Upperwhisker and lowerwhisker.
Lowerwhisker = q1-(1.5*IQR)

# %%
#Replaying outliers into upperwhisker.
df_num['Unit_Price']=np.where(df_num['Unit_Price']>Upperwhisker,Upperwhisker,df_num['Unit_Price'])

# %%
#Checking the outliers in column Unit_Price using boxplot after handling outliers.
sns.boxplot(df_num['Unit_Price'])
# Out:
# <AxesSubplot:xlabel='Unit_Price'>

# %%
#Calculating the quantiles of Unit_Price.
q1 = np.quantile(df_num['Volume'],0.25)
q2 = np.quantile(df_num['Volume'],0.50)
q3 = np.quantile(df_num['Volume'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 1283850.0 |q2 = 2870600.0|q3 = 6247100.0

# %%
IQR = q3-q1 #Calculating IQR(linear quadratic regulator)
IQR
# Out:
# 4963250.0

# %%
Upperwhisker = q3+(1.5*IQR) #Calculating the Upperwhisker and lowerwhisker.
Lowerwhisker = q1-(1.5*IQR)

# %%
#Replaying outliers into upperwhisker.
df_num['Volume']=np.where(df_num['Volume']>Upperwhisker,Upperwhisker,df_num['Volume'])

# %%
#Checking the outliers in column Unit_Price using boxplot after handling outliers.
sns.boxplot(df_num['Volume'])
# Out:
# <AxesSubplot:xlabel='Volume'>

# %%
#Calculating the quantiles of openingbalance.
q1 = np.quantile(df_num['openingbalance'],0.25)
q2 = np.quantile(df_num['openingbalance'],0.50)
q3 = np.quantile(df_num['openingbalance'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 26.397632889999997 |q2 = 33.119999|q3 = 42.525000250000005

# %%
IQR = q3-q1 #Calculating IQR(linear quadratic regulator)
IQR
# Out:
# 16.127367360000008

# %%
Upperwhisker = q3+(1.5*IQR) #Calculating the Upperwhisker and lowerwhisker.
Lowerwhisker = q1-(1.5*IQR)

# %%
#Replaying outliers into upperwhisker.
df_num['openingbalance']=np.where(df_num['openingbalance']>Upperwhisker,Upperwhisker,df_num['openingbalance'])

# %%
#Checking the outliers in column openingbalance using boxplot after handling outliers.
sns.boxplot(df_num['openingbalance'])
# Out:
# <AxesSubplot:xlabel='openingbalance'>

# %%
#Calculating the quantiles of closingbalance.
q1 = np.quantile(df_num['closingbalance'],0.25)
q2 = np.quantile(df_num['closingbalance'],0.50)
q3 = np.quantile(df_num['closingbalance'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 21.99 |q2 = 33.34|q3 = 51.1175005

# %%
IQR = q3-q1 #Calculating IQR(linear quadratic regulator)
IQR
# Out:
# 29.1275005

# %%
Upperwhisker = q3+(1.5*IQR) #Calculating the Upperwhisker and lowerwhisker.
Lowerwhisker = q1-(1.5*IQR)

# %%
#Replaying outliers into upperwhisker.
df_num['closingbalance']=np.where(df_num['closingbalance']>Upperwhisker,Upperwhisker,df_num['closingbalance'])

# %%
#Checking the outliers in column closingbalance using boxplot after handling outliers.
sns.boxplot(df_num['closingbalance'])
# Out:
# <AxesSubplot:xlabel='closingbalance'>

# %%
#Calculating the quantiles of closingbalance.
q1 = np.quantile(df_num['low'],0.25)
q2 = np.quantile(df_num['low'],0.50)
q3 = np.quantile(df_num['low'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 21.7187496875 |q2 = 32.880001|q3 = 50.415

# %%
IQR = q3-q1 #Calculating IQR(linear quadratic regulator)
IQR
# Out:
# 28.6962503125

# %%
Upperwhisker = q3+(1.5*IQR) #Calculating the Upperwhisker and lowerwhisker.
Lowerwhisker = q1-(1.5*IQR)

# %%
#Replaying outliers into upperwhisker.
df_num['low']=np.where(df_num['low']>Upperwhisker,Upperwhisker,df_num['low'])

# %%
#Checking the outliers in column low using boxplot after handling outliers.
sns.boxplot(df_num['low'])
# Out:
# <AxesSubplot:xlabel='low'>

# %% [markdown]
# #
# Handling outliers created some null values in Age, Salary, Base_pay & Bonus columns as it had outliers over upper whisker and lower whisker.

# %%
df_num
# Out:
#        Age  Salary  Base_pay  Bonus  Unit_Price      Volume  openingbalance  \
# 0      NaN     NaN       NaN    NaN    3.770000  13691975.0        3.750000
# 1      NaN     NaN       NaN    NaN    3.740000  10462800.0        3.850000
# 2      NaN     NaN       NaN    NaN    3.890000  13691975.0        4.230000
# 3      NaN     NaN       NaN    NaN    4.350000  13691975.0        4.260000
# 4      NaN     NaN       NaN    NaN    4.340000  13691975.0        4.790000
# ...    ...     ...       ...    ...         ...         ...             ...
# 4995  72.0     NaN       NaN    NaN  108.196251   3927000.0       33.119999
# 4996   NaN     NaN       NaN    NaN  108.196251   6031900.0       33.119999
# 4997   NaN     NaN       NaN    NaN  108.196251   7949400.0       33.119999
# 4998   NaN     NaN       NaN    NaN  108.196251   3908400.0       33.119999
# 4999   NaN     NaN       NaN    NaN  108.196251   6003300.0       33.119999
#
# ...

# %%
df_num.isnull().sum() ##Looking at the sum of null values in each column.
# Out:
# Age               115
# Salary             77
# Base_pay           83
# Bonus              77
# Unit_Price          0
# Volume              0
# openingbalance      0
# closingbalance      0
# low                 0
# Unit_Sales          0
# Total_Sales         0
# Months              0
# dtype: int64

# %%
#Checking the mean of the column Age as it is normally distributed and calling it to a variable and
#replacing the null values with mean using fillna() function.
mean_value=round(df_num.Age.mean())
df_num['Age']=df_num['Age'].fillna(mean_value)

# %%
#Checking the mean of the column Salary as it is normally distributed and calling it to a variable and
#replacing the null values with mean using fillna() function.
mean_value=df_num['Salary'].mean()
df_num['Salary']=df_num['Salary'].fillna(mean_value)

# %%
#Checking the mean of the column Base_pay as it is normally distributed and calling it to a variable and
#replacing the null values with mean using fillna() function.
mean_value=df_num['Base_pay'].mean()
df_num['Base_pay']=df_num['Base_pay'].fillna(mean_value)

# %%
#Checking the mean of the column Bonus as it is normally distributed and calling it to a variable and
#replacing the null values with mean using fillna() function.
mean_value=df_num['Bonus'].mean()
df_num['Bonus']=df_num['Bonus'].fillna(mean_value)

# %%
df_num
# Out:
#        Age         Salary     Base_pay        Bonus  Unit_Price      Volume  \
# 0     52.0  100799.611045  40410.09183  5039.980552    3.770000  13691975.0
# 1     52.0  100799.611045  40410.09183  5039.980552    3.740000  10462800.0
# 2     52.0  100799.611045  40410.09183  5039.980552    3.890000  13691975.0
# 3     52.0  100799.611045  40410.09183  5039.980552    4.350000  13691975.0
# 4     52.0  100799.611045  40410.09183  5039.980552    4.340000  13691975.0
# ...    ...            ...          ...          ...         ...         ...
# 4995  72.0  100799.611045  40410.09183  5039.980552  108.196251   3927000.0
# 4996  52.0  100799.611045  40410.09183  5039.980552  108.196251   6031900.0
# 4997  52.0  100799.611045  40410.09183  5039.980552  108.196251   7949400.0
# 4998  52.0  100799.611045  40410.09183  5039.980552  108.196251   3908400.0
# 4999  52.0  100799.611045  40410.09183  5039.980552  108.196251   6003300.0
#
# ...

# %%
df=pd.concat([df_cat,df_num],axis=1)#concatinating the dt_cat and df_num data set into df

# %%
df
# Out:
#       Gender Business Dependancies Calls            Type Billing Rating  \
# 0     Female        0           No   Yes  Month-to-month      No    Yes
# 1     Female        0           No   Yes  Month-to-month      No    Yes
# 2       Male        0           No   Yes  Month-to-month     Yes     No
# 3     Female        1           No   Yes  Month-to-month     Yes    Yes
# 4       Male        0           No   Yes  Month-to-month     Yes    Yes
# ...      ...      ...          ...   ...             ...     ...    ...
# 4995  Female        0           No   Yes  Month-to-month      No     No
# 4996    Male        0           No   Yes  Month-to-month     Yes     No
# 4997    Male        0           No   Yes  Month-to-month     Yes     No
# 4998    Male        1           No   Yes  Month-to-month     Yes    Yes
# 4999    Male        0          Yes   Yes        Two year     Yes     No
#
#                 Education   Age         Salary     Base_pay        Bonus  \
# ...

# %%
#we have to convert all the categorical columns to numerical columns using map function.
df['Gender'] = df['Gender'].map({'Female': 0, 'Male': 1})
df['Dependancies'] = df['Dependancies'].map({'No': 0, 'Yes': 1})
df['Calls'] = df['Calls'].map({'No': 0, 'Yes': 1})
df['Type'] = df['Type'].map({'Month-to-month': 0, 'One year': 1, 'Two year':2})
df['Billing'] = df['Billing'].map({'No': 0, 'Yes': 1})
df['Rating'] = df['Rating'].map({'No': 0, 'Yes': 1})
df['Education'] = df['Education'].map({'High School or less': 0, 'Intermediate': 1, 'Graduation': 2 ,'PG':3})

# %%
df.head() #Looking the head of the data set which is top 5 columns of the data after converting.
# Out:
#    Gender Business  Dependancies  Calls  Type  Billing  Rating  Education  \
# 0       0        0             0      1     0        0       1          0
# 1       0        0             0      1     0        0       1          0
# 2       1        0             0      1     0        1       0          0
# 3       0        1             0      1     0        1       1          0
# 4       1        0             0      1     0        1       1          0
#
#     Age         Salary     Base_pay        Bonus  Unit_Price      Volume  \
# 0  52.0  100799.611045  40410.09183  5039.980552        3.77  13691975.0
# 1  52.0  100799.611045  40410.09183  5039.980552        3.74  10462800.0
# 2  52.0  100799.611045  40410.09183  5039.980552        3.89  13691975.0
# 3  52.0  100799.611045  40410.09183  5039.980552        4.35  13691975.0
# 4  52.0  100799.611045  40410.09183  5039.980552        4.34  13691975.0
#
#    openingbalance  closingbalance   low  Unit_Sales  Total_Sales  Months
# ...

# %%
df.Business = df.Business.astype('int')

# %%
df.dtypes #Checking the datatype of the columns.
# Out:
# Gender              int64
# Business            int32
# Dependancies        int64
# Calls               int64
# Type                int64
# Billing             int64
# Rating              int64
# Education           int64
# Age               float64
# Salary            float64
# Base_pay          float64
# Bonus             float64
# Unit_Price        float64
# Volume            float64
# openingbalance    float64
# closingbalance    float64
# low               float64
# Unit_Sales        float64
# Total_Sales       float64
# Months              int64
# dtype: object

# %%
#Return the absolute value of the argument as spearman rank correlation more than 0.7 and call the highly correlated columns.
abs(df_num.corr(method='spearman')['Salary'][df_num.corr(method='spearman')['Salary']>0.7].drop('Salary'))
# Out:
# Base_pay       0.991651
# Bonus          1.000000
# Unit_Price     0.791418
# low            0.977147
# Unit_Sales     0.977027
# Total_Sales    0.978362
# Name: Salary, dtype: float64

# %% [markdown]
# Base_pay,Bonus,Unit_Price,low,Unit_Sales,Total_Sales columns has highest corelation.

# %% [markdown]
# #### iii. Feature Selection

# %% [markdown]
# Now we will choose the features we want to work on on the basis of the correlation operation performed on the numerical features and boxplot analysis done on the categorical features and we are selecting bonus,Unit_Price,Unit_Sales,Low, Education,Total_Sales,Base_Pay unit prize from numerical features and Education from categorical features.

# %%
#Giving the independent variables to x
x=pd.DataFrame(data=df,columns=['Education','Base_pay','Bonus','Unit_Price','low','Unit_Sales','Total_Sales']) #independent variables
y=pd.DataFrame(df['Salary']) #dependent variable

# %%
#Importing train_test_split from sklearn.model_selection to test and train the model by giving the test size as 0.25(25%) which 
#makes train size as 0.75(75%) as default and random state as 1.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1)

# %%
x_train.shape #Checking the shape of x_train.
# Out:
# (3750, 7)

# %%
x_test.shape #Checking the shape of x_test.
# Out:
# (1250, 7)

# %%
y_train.shape #Checking the shape of y_train.
# Out:
# (3750, 1)

# %%
y_test.shape #Checking the shape of y_test.
# Out:
# (1250, 1)

# %%
#importing minmaxscaler from sklearn.preprocessing to normalize the data, fit_transform to fit minmaxscaler to data and transform into data.
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
x_train_scaled = scaler.fit_transform(x_train)
x_train = pd.DataFrame(x_train_scaled)

# %%
#fit_transform to fit minmaxscaler to data and transform into data.
x_test_scaled = scaler.fit_transform(x_test)
x_test = pd.DataFrame(x_test_scaled)

# %% [markdown]
# ### 6.Apply ML algorithm to the pre-processed columns and find out, which of these algorithms is best suitable for the same

# %% [markdown]
# # DecisionTreeRegressor

# %%
#Importing DecisionTreeRegressor from sklearn.tree library.
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics   #Importing metrics from sklearn library
from sklearn.metrics import r2_score #Importing r2 score from sklearn library
#Calling DecisionTreeRegressor with max_depth as 3 and calling it to dtReg.
dtReg= DecisionTreeRegressor(max_depth=3)

# %%
#Fitting x_train,y_train to dtReg.
dtReg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
y_pred=dtReg.predict(x_train) #prediction of y_train
print(' r2 score for Training :',r2_score(y_train,y_pred)) #print of r2 score for train
print('Mean Absolute Error for Training: ',metrics.mean_absolute_error(y_train,y_pred))#Print MSE value for train
print('Mean Squared Error for Training: ',metrics.mean_squared_error(y_train,y_pred))  #Print MSE value for train
print('Root Mean Squared Error for Training: ',np.sqrt(metrics.mean_squared_error(y_train,y_pred)))  #Print RMSE value for train
print()

y_pred=dtReg.predict(x_test) #prediction of y_test
print(' r2 score for Testing :',r2_score(y_test,y_pred))#print of r2 score for test
print('Mean Absolute Error for Testing : ',metrics.mean_absolute_error(y_test,y_pred)) #Print MSE value for test
print('Mean Squared Error for Testing: ',metrics.mean_squared_error(y_test,y_pred)) #Print MSE value for test
print('Root Mean Squared Error for Testing: ',np.sqrt(metrics.mean_squared_error(y_test,y_pred))) #Print RMSE value for test
# Out:
#  r2 score for Training : 0.969320862589405
# Mean Absolute Error for Training:  3324.25069647593
# Mean Squared Error for Training:  16385381.75594819
# Root Mean Squared Error for Training:  4047.8860848532026
#
#  r2 score for Testing : 0.9545728869249501
# Mean Absolute Error for Testing :  3934.8011511609234
# Mean Squared Error for Testing:  23449097.17999702
# Root Mean Squared Error for Testing:  4842.426786229918

# %%
#predicting the random train value by giving random values to dtReg.predict.
predict_value=dtReg.predict([[5039.980552,4.350000,18.75,3.830000,0,19.00,40410.09183]])
print('predict_value:',predict_value)
# Out:
# predict_value: [146521.4549161]

# %% [markdown]
# ## Decision Tree Regressor Accuracy is: 95.57

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor # import the regressor
from sklearn import metrics
from sklearn.metrics import r2_score
rfr = RandomForestRegressor(random_state=5)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=5)

# %%
#By using rfr.predict function on x_test and calling it to y_predict to predict a value.
Y_pred = rfr.predict(x_test)

# %%
y_pred=rfr.predict(x_train) #prediction of y_train
print(' r2 score for Training :',r2_score(y_train,y_pred)) #print of r2 score for train
print('Mean Absolute Error for Training: ',metrics.mean_absolute_error(y_train,y_pred))#Print MSE value for train
print('Mean Squared Error for Training: ',metrics.mean_squared_error(y_train,y_pred))  #Print MSE value for train
print('Root Mean Squared Error for Training: ',np.sqrt(metrics.mean_squared_error(y_train,y_pred)))  #Print RMSE value for train
print()

y_pred=rfr.predict(x_test) #prediction of y_test
print(' r2 score for Testing :',r2_score(y_test,y_pred))#print of r2 score for test
print('Mean Absolute Error for Testing : ',metrics.mean_absolute_error(y_test,y_pred)) #Print MSE value for test
print('Mean Squared Error for Testing: ',metrics.mean_squared_error(y_test,y_pred)) #Print MSE value for test
print('Root Mean Squared Error for Testing: ',np.sqrt(metrics.mean_squared_error(y_test,y_pred))) #Print RMSE value for test
# Out:
#  r2 score for Training : 0.9999267303511785
# Mean Absolute Error for Training:  12.293901500592666
# Mean Squared Error for Training:  39132.494209225064
# Root Mean Squared Error for Training:  197.81934740875337
#
#  r2 score for Testing : 0.990591091171517
# Mean Absolute Error for Testing :  1635.166676989647
# Mean Squared Error for Testing:  4856800.323461597
# Root Mean Squared Error for Testing:  2203.8149476445606

# %%
#predicting the random train value by giving random values to rtr.predict.
predict_value=dtReg.predict([[5039.980552,4.350000,18.75,3.830000,0,19.00,40410.09183]])
print('predict_value:',predict_value)
# Out:
# predict_value: [146521.4549161]

# %% [markdown]
# ## Random Forest Regressor Accuracy is: 99

# %% [markdown]
# # LinearRegression

# %%
#Importing LineaarRegression from sklear.linear_model and importing mean_squared_error, r2_score from sklearn.metrics
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# Calling LinearRegression() as lr
lr=LinearRegression()

# %%
#Fitting x_train,y_train to lr.
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#By using lr.predict function on x_test and calling it to y_train_predict to predict a value 
y_train_predict=lr.predict(x_train)

# %%
#Calculating and Printing Mean Squared Error (MSE),R2 score(R2)
print('Mean Squared Error (MSE):', np.sqrt(mean_squared_error(y_train,y_train_predict)))
print('R2 score(R2):', r2_score(y_train, y_train_predict))
# Out:
# Mean Squared Error (MSE): 3.642603044383611e-06
# R2 score(R2): 1.0

# %%
y_test_predict=lr.predict(x_test)

# %%
#Calculating and Printing Mean Squared Error (MSE),R2 score(R2)
print('Mean Squared Error (MSE):', np.sqrt(mean_squared_error(y_test,y_test_predict)))
print('R2 score(R2):', r2_score(y_test, y_test_predict))
# Out:
# Mean Squared Error (MSE): 3018.4871141201816
# R2 score(R2): 0.9823490671040291

# %%
predict_value=round(r2_score(y_test, y_test_predict)*100,2)
print('predict_value:',predict_value)
# Out:
# predict_value: 98.23

# %%
#predicting the random train value by giving random values to lr.predict.
predict_value=dtReg.predict([[5039.980552,4.350000,18.75,3.830000,0,19.00,40410.09183]])
print('predict_value:',predict_value)
# Out:
# predict_value: [146521.4549161]

# %% [markdown]
# ## LineaarRegression Accuracy is: 98.23

# %% [markdown]
# ## Results and Conclusion
# we have done all the elementry EDA steps needed and plotted various graphs to determine the correlation among the independent variables and also between the independent and dependent variable. Then on basis of that we selected our most important independent variables.
# After feature selection we used three machine learning models and achieved quite good accuracy.

# %% [markdown]
# Salary is highly affected by the education more educated person is taking more salary,more experienced people are also getting higher salary and the bonus is also paid according to the salary.As an HR I can motivate employee to sell more items so they could get more bonus and our sales can also increase.

# %% [markdown]
# ## By applying ML algorithm to the pre-processed columns we found good accuracy

# %% [markdown]
# ## Decision Tree Regressor Accuracy is: 93.56

# %% [markdown]
# ## Random Forest Regressor Accuracy is: 99

# %% [markdown]
# ## LineaarRegression Accuracy is: 98.23

# %% [markdown]
# ## We found high accuracy in Random Forest Regressor Accuracy is: 99

# %% [markdown]
# # THANK YOU
